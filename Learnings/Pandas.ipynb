# %%
import pandas as pd
data={
    "name":['abi','jack','sheetal'],
    'age':[25,26,45],
    'salary':[25000,30000,30000]
}
df=pd.DataFrame(data)
df
# Out:
#       name  age  salary
# 0      abi   25   25000
# 1     jack   26   30000
# 2  sheetal   45   30000

# %%
df=pd.read_csv(r"C:\Users\Daniel\Downloads\Python pract\Pandas\orders.csv")
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020             NaN    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454              NaN  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.head(10)
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 6  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 7  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 8  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 9  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# ...

# %%
df.tail(10)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 40  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 41  CA-2021-120999  10-09-2021  15-09-2021  Standard Class    LC-16930
# 42  CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 43  CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 44  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#      region       product_id         category  sales  quantity  profit
# 40  Central  TEC-PH-10000486       Technology  371.2         4    41.8
# ...

# %%
df.dtypes
# Out:
# order_id        object
# order_date      object
# ship_date       object
# ship_mode       object
# customer_id     object
# region          object
# product_id      object
# category        object
# sales          float64
# quantity         int64
# profit         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     50 non-null     object
#  1   order_date   50 non-null     object
#  2   ship_date    50 non-null     object
#  3   ship_mode    50 non-null     object
#  4   customer_id  50 non-null     object
#  5   region       50 non-null     object
#  6   product_id   50 non-null     object
#  7   category     50 non-null     object
#  8   sales        50 non-null     float64
#  9   quantity     50 non-null     int64
#  10  profit       50 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 4.4+ KB

# %%
df.describe()
# Out:
#              sales   quantity       profit
# count    50.000000  50.000000    50.000000
# mean    300.792000   3.920000   -20.550000
# std     547.564035   1.977836   251.767027
# min       2.500000   2.000000 -1665.100000
# 25%      20.075000   2.000000     2.500000
# 50%      74.650000   3.000000     8.350000
# 75%     249.875000   5.000000    17.650000
# max    3083.400000   9.000000   240.300000

# %%
df.shape
# Out:
# (50, 11)

# %%
df.columns =['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df=pd.read_csv(r"C:\Users\Daniel\Downloads\Python pract\Pandas\orders.csv") #header=None
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.columns =['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
col=['order_id','order_date','ship_date']
df_new=df['order_id']
df_new.head()
# Out:
# 0    CA-2020-152156
# 1    CA-2020-152156
# 2    CA-2020-138688
# 3    US-2019-108966
# 4    US-2019-108966
# Name: order_id, dtype: object

# %%
type(df_new)
# Out:
# pandas.core.series.Series

# %%
df.iloc[:4]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0

# %%
df.iloc[[2,5,8]]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 8  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 5  FUR-FU-10001487        Furniture   48.9         7    14.2
# 8  OFF-BI-10003910  Office Supplies   18.5         3     5.8

# %%
df.iloc[[2,5,8],5:7] # we slice based on the index iloc(index location)
# Out:
#   region       product_id
# 2   West  OFF-LA-10000240
# 5   West  FUR-FU-10001487
# 8   West  OFF-BI-10003910

# %%
df.iloc[[2,5,8],[2,4,6]]
# Out:
#     ship_date customer_id       product_id
# 2  16-06-2020    DV-13045  OFF-LA-10000240
# 5  14-06-2018    BH-11710  FUR-FU-10001487
# 8  14-06-2018    BH-11710  OFF-BI-10003910

# %%
df.loc[0:10,['order_id','order_date','sales']]
# Out:
#           order_id  order_date   sales
# 0   CA-2020-152156  08-11-2020   262.0
# 1   CA-2020-152156  08-11-2020   731.9
# 2   CA-2020-138688  12-06-2020    14.6
# 3   US-2019-108966  11-10-2019   957.6
# 4   US-2019-108966  11-10-2019    22.4
# 5   CA-2018-115812  09-06-2018    48.9
# 6   CA-2018-115812  09-06-2018     7.3
# 7   CA-2018-115812  09-06-2018   907.2
# 8   CA-2018-115812  09-06-2018    18.5
# 9   CA-2018-115812  09-06-2018   114.9
# 10  CA-2018-115812  09-06-2018  1706.2

# %%
df.set_index('order_id')
# Out:
#                 order_date   ship_date       ship_mode customer_id   region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045     West
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# ...

# %%
df.set_index('order_id',inplace=True)

# %%
df
# Out:
#                 order_date   ship_date       ship_mode customer_id   region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045     West
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# ...

# %%
df.loc['CA-2020-152156','order_date':'customer_id']
# Out:
#                 order_date   ship_date     ship_mode customer_id
# order_id
# CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520
# CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520

# %%
df.iloc['CA-2020-152156','order_date':'customer_id']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Anaconda\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File ~\Anaconda\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df.iloc['CA-2020-152156','order_date':'customer_id']
#
# ...

# %%
df.loc[['CA-2020-152156','US-2019-118983'],['ship_date','order_date']]
# Out:
#                  ship_date  order_date
# order_id
# CA-2020-152156  11-11-2020  08-11-2020
# CA-2020-152156  11-11-2020  08-11-2020
# US-2019-118983  26-11-2019  22-11-2019
# US-2019-118983  26-11-2019  22-11-2019

# %%
#df.reset_index(inplace=True)
df=df.drop(['level_0','index'],axis=1)

# %%
#sort based on index
df.sort_index()
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.sort_index(ascending=False,inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 44  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 43  CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 42  CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 41  CA-2021-120999  10-09-2021  15-09-2021  Standard Class    LC-16930
# 40  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 39  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 38  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# ...

# %%
df.sort_index(ascending=True,inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
#order with highest sales
df.sort_values('sales',ascending=False)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 27  US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 35  CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
# 24  CA-2019-106320  25-09-2019  30-09-2019  Standard Class    EB-13870
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 16  CA-2018-105893  11-11-2018  18-11-2018  Standard Class    PK-19075
# 38  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 13  CA-2020-161389  05-12-2020  10-12-2020  Standard Class    IM-15070
# 40  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# ...

# %%
#sort by first column then sort by second column
df.sort_values(['quantity','profit'],ascending=[True,False],inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %%
#data filteration
fc=df['region']=='South'
df.loc[fc]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  South
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900  South
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945  South
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885  South
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# ...

# %%
df.loc[df['region']=='South',['order_id','order_date']]
# Out:
#           order_id  order_date
# 0   CA-2020-152156  08-11-2020
# 1   CA-2020-118255  11-03-2020
# 2   CA-2018-167164  13-05-2018
# 3   CA-2021-139619  19-09-2021
# 4   CA-2020-118255  11-03-2020
# 5   CA-2020-138688  12-06-2020
# 6   CA-2020-169194  20-06-2020
# 7   CA-2020-121755  16-01-2020
# 8   CA-2020-101343  17-07-2020
# 9   US-2019-150630  17-09-2019
# 10  US-2019-108966  11-10-2019
# 11  CA-2018-143336  27-08-2018
# 12  US-2019-150630  17-09-2019
# 13  US-2021-156909  16-07-2021
# 14  US-2019-150630  17-09-2019
# 15  CA-2019-106320  25-09-2019
# 16  CA-2020-152156  08-11-2020
# 17  CA-2020-161389  05-12-2020
# 18  CA-2018-143336  27-08-2018
# 19  US-2019-150630  17-09-2019
# 20  CA-2020-121755  16-01-2020
# 21  CA-2021-107727  19-10-2021
# 22  CA-2018-115812  09-06-2018
# 23  CA-2021-114412  15-04-2021
# 24  CA-2020-169194  20-06-2020
# 25  US-2019-118983  22-11-2019
# 26  CA-2019-117415  27-12-2019
# 27  CA-2019-117415  27-12-2019
# 28  CA-2018-115812  09-06-2018
# ...

# %%
df.loc[(df['region']=='South') & (df['profit']>0) & (df['ship_mode']=='First Class')]
# Out:
#           order_id  order_date   ship_date    ship_mode customer_id region  \
# 1   CA-2020-118255  11-03-2020  13-03-2020  First Class    ON-18715  South
# 4   CA-2020-118255  11-03-2020  13-03-2020  First Class    ON-18715  South
# 43  CA-2020-117590  08-12-2020  10-12-2020  First Class    GH-14485  South
#
#          product_id         category   sales  quantity  profit
# 1   TEC-AC-10000171       Technology    46.0         2    19.8
# 4   OFF-BI-10003291  Office Supplies    17.5         2     8.2
# 43  TEC-PH-10004977       Technology  1097.5         7   123.5

# %%
df[df['region']=='South']
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  South
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900  South
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945  South
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885  South
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# ...

# %%
#inverse filter
df[-(df['region']=='South')]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_id, region, product_id, category, sales, quantity, profit]
# Index: []

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  South
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900  South
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945  South
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885  South
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# ...

# %%
df['country']='India'

# %%
df['country']='USA'

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  South
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900  South
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945  South
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885  South
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# ...

# %%
df.drop(columns='country',inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  South
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900  South
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945  South
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885  South
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# ...

# %%
df['profit_flag']=1

# %%
df.loc[df['profit']<=0,'profit_flag']=0

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  South
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900  South
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945  South
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885  South
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# ...

# %%
# <0-->loss
# between 0 and 50-->low profit
# >50 high profit
df['profit_status']='status'
df.loc[df['profit']<0,'profit_status']='loss'
df.loc[(df['profit']>=0) & (df['profit']<=50),'profit_status']='low profit'
df.loc[(df['profit']>50),'profit_status']='high profit'

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  South
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900  South
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945  South
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885  South
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# ...

# %%
df.drop(columns=['profit_flag','profit_status'],inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  South
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900  South
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945  South
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885  South
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# ...

# %%
df['category_len']=df['category'].apply(len)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  South
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900  South
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945  South
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885  South
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# ...

# %%
def profit_loss(profit):
    if profit>0:
        return "profit"
    else:
        return"loss"
df['profit_loss']=df['profit'].apply(profit_loss)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715  South
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  South
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900  South
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945  South
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885  South
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# ...

# %%
name="daniel"
type(name)
# Out:
# str

# %%
name.startswith("d")
# Out:
# True

# %%
df['category'].str.upper()
# Out:
# 0           FURNITURE
# 1           FURNITURE
# 2     OFFICE SUPPLIES
# 3           FURNITURE
# 4     OFFICE SUPPLIES
# 5           FURNITURE
# 6     OFFICE SUPPLIES
# 7          TECHNOLOGY
# 8     OFFICE SUPPLIES
# 9     OFFICE SUPPLIES
# 10          FURNITURE
# 11         TECHNOLOGY
# 12    OFFICE SUPPLIES
# 13    OFFICE SUPPLIES
# 14    OFFICE SUPPLIES
# 15    OFFICE SUPPLIES
# 16    OFFICE SUPPLIES
# 17    OFFICE SUPPLIES
# 18    OFFICE SUPPLIES
# 19         TECHNOLOGY
# 20    OFFICE SUPPLIES
# 21    OFFICE SUPPLIES
# 22    OFFICE SUPPLIES
# 23          FURNITURE
# 24          FURNITURE
# 25    OFFICE SUPPLIES
# 26         TECHNOLOGY
# 27          FURNITURE
# 28    OFFICE SUPPLIES
# 29          FURNITURE
# 30    OFFICE SUPPLIES
# 31    OFFICE SUPPLIES
# 32    OFFICE SUPPLIES
# 33    OFFICE SUPPLIES
# 34    OFFICE SUPPLIES
# 35         TECHNOLOGY
# 36          FURNITURE
# 37    OFFICE SUPPLIES
# 38          FURNITURE
# 39          FURNITURE
# 40         TECHNOLOGY
# ...

# %%
df['category_upper']=df['category'].str.upper()

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.drop(columns='category_upper',axis=1,inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
#file read after removing values in the file
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020             NaN    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.isnull().sum()
# Out:
# order_id       0
# order_date     0
# ship_date      0
# ship_mode      1
# customer_id    0
# region         0
# product_id     0
# category       1
# sales          0
# quantity       0
# profit         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     50 non-null     object
#  1   order_date   50 non-null     object
#  2   ship_date    50 non-null     object
#  3   ship_mode    49 non-null     object
#  4   customer_id  50 non-null     object
#  5   region       50 non-null     object
#  6   product_id   50 non-null     object
#  7   category     49 non-null     object
#  8   sales        50 non-null     float64
#  9   quantity     50 non-null     int64
#  10  profit       50 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 4.4+ KB

# %%
df.dropna(inplace=True)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 12  CA-2021-114412  15-04-2021  20-04-2021  Standard Class    AA-10480
# 13  CA-2020-161389  05-12-2020  10-12-2020  Standard Class    IM-15070
# ...

# %%
df.dropna(subset=['category','ship_mode'])# it will check null values for the subset column
# it is true the column will be dropped
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 12  CA-2021-114412  15-04-2021  20-04-2021  Standard Class    AA-10480
# 13  CA-2020-161389  05-12-2020  10-12-2020  Standard Class    IM-15070
# ...

# %%
df.fillna("unknown",inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020         unknown    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df['category'].fillna('unknown',inplace=True)
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_1328\4273976590.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['category'].fillna('unknown',inplace=True)

# %%
df['sales'].fillna(df['sales'].mean(),inplace=True)
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_1328\1971190938.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sales'].fillna(df['sales'].mean(),inplace=True)

# %%
# First forward fill
df.fillna(method='ffill', inplace=True)
print("\nAfter forward fill:")
print(df)

# Then backward fill
df.fillna(method='bfill', inplace=True)
print("\nAfter backward fill:")
print(df)

# %%
#drop duplicate
import pandas as pd
data={
    "name":['abi','jack','sheetal','jack'],
    'age':[25,30,30,30],
    'salary':[25000,30000,30000,30000]
}
df=pd.DataFrame(data)
df
# Out:
#       name  age  salary
# 0      abi   25   25000
# 1     jack   30   30000
# 2  sheetal   30   30000
# 3     jack   30   30000

# %%
#drop duplicates will drop last index to keep last index keep=last is mentioned
df.drop_duplicates(keep='last')
# Out:
#       name  age  salary
# 0      abi   25   25000
# 2  sheetal   30   30000
# 3     jack   30   30000

# %%
df.drop_duplicates(subset=['age','salary'],keep='first')
# Out:
#    name  age  salary
# 0   abi   25   25000
# 1  jack   30   30000

# %%
df.dtypes
# Out:
# order_id        object
# order_date      object
# ship_date       object
# ship_mode       object
# customer_id     object
# region          object
# product_id      object
# category        object
# sales          float64
# quantity         int64
# profit         float64
# dtype: object

# %%
df['order_date']=pd.to_datetime(df['order_date'], format ='%d-%m-%Y')
df
# Out:
#           order_id order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156 2020-11-08  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156 2020-11-08  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688 2020-06-12  16-06-2020             NaN    DV-13045
# 3   US-2019-108966 2019-10-11  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966 2019-10-11  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812 2018-06-09  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812 2018-06-09  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812 2018-06-09  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812 2018-06-09  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812 2018-06-09  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812 2018-06-09  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812 2018-06-09  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.dtypes
# Out:
# order_id               object
# order_date     datetime64[ns]
# ship_date              object
# ship_mode              object
# customer_id            object
# region                 object
# product_id             object
# category               object
# sales                 float64
# quantity                int64
# profit                float64
# dtype: object

# %%
df['ship_date']=pd.to_datetime(df['ship_date'],format='%d-%m-%Y')
df
# Out:
#           order_id order_date  ship_date       ship_mode customer_id   region  \
# 0   CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520    South
# 1   CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520    South
# 2   CA-2020-138688 2020-06-12 2020-06-16             NaN    DV-13045     West
# 3   US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335    South
# 4   US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335    South
# 5   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 6   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 7   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 8   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 9   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 10  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# ...

# %%
df.dtypes
# Out:
# order_id               object
# order_date     datetime64[ns]
# ship_date      datetime64[ns]
# ship_mode              object
# customer_id            object
# region                 object
# product_id             object
# category               object
# sales                 float64
# quantity                int64
# profit                float64
# dtype: object

# %%
#df['order_date'].dt.year
df['order_date'].dt.month
# Out:
# 0     11
# 1     11
# 2      6
# 3     10
# 4     10
# 5      6
# 6      6
# 7      6
# 8      6
# 9      6
# 10     6
# 11     6
# 12     4
# 13    12
# 14    11
# 15    11
# 16    11
# 17     5
# 18     8
# 19     8
# 20     8
# 21    12
# 22    12
# 23     7
# 24     9
# 25     1
# 26     1
# 27     9
# 28     9
# 29     9
# 30     9
# 31     9
# 32     9
# 33     9
# 34    10
# 35    12
# 36    12
# 37    12
# 38    12
# 39    12
# 40    12
# 41     9
# 42     7
# 43     9
# 44     3
# 45     3
# 46    10
# 47     6
# 48     6
# 49     4
# Name: order_date, dtype: int32

# %%
df[df['order_date']>='2021-01-01']
# Out:
#           order_id order_date  ship_date       ship_mode customer_id   region  \
# 12  CA-2021-114412 2021-04-15 2021-04-20  Standard Class    AA-10480    South
# 23  US-2021-156909 2021-07-16 2021-07-18    Second Class    SF-20065     East
# 34  CA-2021-107727 2021-10-19 2021-10-23    Second Class    MA-17560  Central
# 41  CA-2021-120999 2021-09-10 2021-09-15  Standard Class    LC-16930  Central
# 43  CA-2021-139619 2021-09-19 2021-09-23  Standard Class    ES-14080    South
#
#          product_id         category  sales  quantity  profit
# 12  OFF-PA-10002365  Office Supplies   15.6         3     5.4
# 23  FUR-CH-10002774        Furniture   71.4         2    -1.0
# 34  OFF-PA-10000249  Office Supplies   29.5         3     9.9
# 41  TEC-PH-10004093       Technology  147.2         4    16.6
# 43  OFF-ST-10003282  Office Supplies   95.6         2     9.6

# %%
#date difference
df['transit_days']=(df['ship_date']-df['order_date']).dt.days
df
# Out:
#           order_id order_date  ship_date       ship_mode customer_id   region  \
# 0   CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520    South
# 1   CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520    South
# 2   CA-2020-138688 2020-06-12 2020-06-16             NaN    DV-13045     West
# 3   US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335    South
# 4   US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335    South
# 5   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 6   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 7   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 8   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 9   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 10  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# ...

# %%
#aggregation
var_sum=df['sales'].sum()
var_mean=df['sales'].mean()
var_min=df['sales'].min()
print(f"{var_sum} {var_mean} {var_min}")
print(str(var_sum) + " " + str(var_mean) + " " + str(var_min))
print(f"{var_sum} {var_mean} {var_min}")
print("{} {} {}".format(var_sum, var_mean, var_min))
print(var_sum, var_mean, var_min)
# Out:
# 15039.599999999999 300.792 2.5
# 15039.599999999999 300.792 2.5
# 15039.599999999999 300.792 2.5
# 15039.599999999999 300.792 2.5
# 15039.599999999999 300.792 2.5

# %%
df['region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['category'].unique()
# Out:
# array(['Furniture', nan, 'Office Supplies', 'Technology'], dtype=object)

# %%
df.groupby("region")["sales"].sum()
# Out:
# region
# Central    3824.8
# East       3467.7
# South      2085.1
# West       5662.0
# Name: sales, dtype: float64

# %%
df.groupby("region")["sales"].agg(["min","max","sum"])
# Out:
#           min     max     sum
# region
# Central   2.5  1097.5  3824.8
# East      3.3  3083.4  3467.7
# South    15.6   957.6  2085.1
# West      7.3  1706.2  5662.0

# %%
df.groupby('category').agg({'sales':'sum','profit':['sum','max']})
# Out:
#                   sales  profit
#                     sum     sum    max
# category
# Furniture        8233.7 -1862.0  240.3
# Office Supplies  2222.6   215.2  132.6
# Technology       3851.4   399.7  123.5

# %%
df['category'].value_counts()
# Out:
# category
# Office Supplies    28
# Furniture          11
# Technology         10
# Name: count, dtype: int64

# %%
pd.pivot_table(
    df,
    index='region',
    columns='category',
    values='sales',
    aggfunc="sum",
    fill_value=0
)
# Out:
# category  Furniture  Office Supplies  Technology
# region
# Central       935.4           1227.5      1661.9
# East         3279.0            121.9        66.8
# South        1219.6            133.6         0.0
# West         2799.7            739.6      2122.7

# %%
#join
df_orders=pd.read_csv(r"C:\Users\Daniel\Downloads\Python pract\Pandas\orders.csv")
df_returns=pd.read_csv(r"C:\Users\Daniel\Downloads\Python pract\Pandas\returns.csv")

# %%
df_returns
# Out:
#   return_order_id return_reason
# 0  CA-2018-105893   bad quality
# 1  CA-2018-143336    wrong item
# 2  CA-2018-146703    wrong item
# 3  CA-2018-167164         other
# 4  CA-2019-106320   bad quality
# 5  CA-2019-115742         other
# 6  CA-2020-101343   bad quality
# 7  CA-2020-117590    wrong item

# %%
df=pd.merge(left=df_orders,right=df_returns,on='order_id',how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14772\679952641.py in ?()
# ----> 1 df=pd.merge(left=df_orders,right=df_returns,on='order_id',how='inner')
#
# ~\Anaconda\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~\Anaconda\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
# ...

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2018-105893  11-11-2018  18-11-2018  Standard Class    PK-19075
# 1   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 2   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 3   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 4   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 5   CA-2019-106320  25-09-2019  30-09-2019  Standard Class    EB-13870
# 6   CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
# 7   CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 10  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#      region       product_id         category   sales  quantity  profit  \
# ...

# %%
df.groupby('return_reason')['sales'].sum()
# Out:
# return_reason
# bad quality    1788.4
# other            93.7
# wrong item     1745.2
# Name: sales, dtype: float64

# %%
df=pd.merge(left=df_orders,right=df_returns,on='order_id',how='left')
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.groupby('return_reason')['sales'].sum()
# Out:
# return_reason
# bad quality    1788.4
# other            93.7
# wrong item     1745.2
# Name: sales, dtype: float64

# %%
#cross join don't have to join mention 'on' coz each row join with all the row in the sec table
df=pd.merge(left=df_orders,right=df_returns,how='cross')
df
# Out:
#          order_id_x  order_date   ship_date       ship_mode customer_id  \
# 0    CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1    CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2    CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 3    CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 4    CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# ..              ...         ...         ...             ...         ...
# 395  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
# 396  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
# 397  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
# 398  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
# 399  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#       region       product_id         category  sales  quantity  profit  \
# ...

# %%
df=pd.merge(left=df_orders,right=df_returns,left_on='order_id',right_on='return_order_id', how='left')

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
emp1={"id":[1,2,3],
      "name":["Ankit","Sumit","Ankit"],
      "salary":[100,200,300]}
emp2={"id":[4,5,6],
      "name":["Nachiket","Rahul","Vinay"],
      "salary":[400,500,600]}
df1=pd.DataFrame(emp1)
df2=pd.DataFrame(emp2)

# %%
df1
# Out:
#    id   name  salary
# 0   1  Ankit     100
# 1   2  Sumit     200
# 2   3  Ankit     300

# %%
df2
# Out:
#    id      name  salary
# 0   4  Nachiket     400
# 1   5     Rahul     500
# 2   6     Vinay     600

# %%
#union
df=pd.concat([df1,df2],ignore_index=True)
df
# Out:
#    id      name  salary
# 0   1     Ankit     100
# 1   2     Sumit     200
# 2   3     Ankit     300
# 3   4  Nachiket     400
# 4   5     Rahul     500
# 5   6     Vinay     600

# %%
df.reset_index()
# Out:
#    index  id      name  salary
# 0      0   1     Ankit     100
# 1      1   2     Sumit     200
# 2      2   3     Ankit     300
# 3      0   4  Nachiket     400
# 4      1   5     Rahul     500
# 5      2   6     Vinay     600

# %%
#write data bar
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.to_excel("full_orders.xlsx",index=False)

# %%
import pandas as pd
df_excel=pd.read_excel("full_orders.xlsx")

# %%
df_excel
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df_excel=pd.read_excel("full_orders.xlsx",sheet_name='orders2')

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
#mysql
! pip install mysql-connector-python sqlalchemy pandas pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    --- ------------------------------------ 1.6/16.4 MB 7.6 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/16.4 MB 7.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.7/16.4 MB 7.5 MB/s eta 0:00:02
#    --------------- ------------------------ 6.3/16.4 MB 7.4 MB/s eta 0:00:02
#    ------------------- -------------------- 7.9/16.4 MB 7.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/16.4 MB 7.4 MB/s eta 0:00:01
#    -------------------------- ------------- 11.0/16.4 MB 7.4 MB/s eta 0:00:01
#    ------------------------------ --------- 12.6/16.4 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.2/16.4 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 15.7/16.4 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 7.3 MB/s  0:00:02
# ...
#
# ...

# %%
from sqlalchemy import create_engine,text
import pandas as pd
engine=create_engine("mysql+pymysql://root:Password@127.0.0.1:3306/daniel")

# %%
query="select * from user_tab"
df=pd.read_sql(query,con=engine)

# %%
df
# Out:
#    id    name
# 0  34  daniel

# %%
df=pd.read_csv(r"C:\Users\Daniel\Downloads\Python pract\Pandas\orders.csv")

# %%
df.to_sql(name="order",con=engine,index=False,if_exists="replace")
# Out:
# 50

# %%
df.to_sql(name="order",con=engine,index=False,if_exists="fail")
#error when the table exist already
# Out:
# 50

# %%
df.to_sql(name="order",con=engine,index=False,if_exists="append")
# Out:
# 50

# %%
truncate table
insert table

# %%
# query=text("truncate table order")
# with engine.begin() as conn:
#     conn.execute(query)
#     conn.commit()

query = text("TRUNCATE TABLE `order`;")
with engine.begin() as conn:
    conn.execute(query)
    conn.commit()
    #update order set region='North' where order_id='CA-2020-152156'
